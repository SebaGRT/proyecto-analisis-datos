# %% [markdown]
# # Proyecto de Investigación - Cambios temporales en la carga hospitalaria
#
# ## Integrantes
# - Sebastián Herrera Sarmiento
# - Benjamín Bravo Albornoz

# %%
# Preparación entorno

import pandas as pd
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('dataset_rem2026.csv', sep=';')
dataset.head(10)
# Out:
#    PERIODO  TIPO_PERTENENCIA  COD_SSS GLOSA_SSS  CODIGO_ESTABLECIMIENTO  \
# 0     2014                 1        1     Arica                  101100
# 1     2014                 1        1     Arica                  101100
# 2     2014                 1        1     Arica                  101100
# 3     2014                 1        1     Arica                  101100
# 4     2014                 1        1     Arica                  101100
# 5     2014                 1        1     Arica                  101100
# 6     2014                 1        1     Arica                  101100
# 7     2014                 1        1     Arica                  101100
# 8     2014                 1        1     Arica                  101100
# 9     2014                 1        1     Arica                  101100
#
#                          ESTABLECIMIENTO  COD_AREA_FUNCIONAL  \
# 0  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 1  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 2  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 3  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 4  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 5  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 6  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 7  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 8  Hospital Dr Juan Noé Crevanni (Arica)                 405
# 9  Hospital Dr Juan Noé Crevanni (Arica)                 405
#
#                       AREA_FUNCIONAL  MES  DIAS_CAMAS_OCUPADAS  \
# 0  Área Cuidados Intensivos Adultos     1                  139
# 1  Área Cuidados Intensivos Adultos     2                  103
# 2  Área Cuidados Intensivos Adultos     3                  117
# 3  Área Cuidados Intensivos Adultos     4                  126
# 4  Área Cuidados Intensivos Adultos     5                  141
# 5  Área Cuidados Intensivos Adultos     6                  135
# 6  Área Cuidados Intensivos Adultos     7                  163
# 7  Área Cuidados Intensivos Adultos     8                  159
# 8  Área Cuidados Intensivos Adultos     9                  156
# 9  Área Cuidados Intensivos Adultos    10                  136
#
#    DIAS_CAMAS_DISPONIBLES  DIAS_ESTADA  NUMERO_EGRESOS  EGRESOS_FALLECIDOS  \
# 0                     186          115               9                   7
# 1                     168          164               7                   4
# 2                     186           98              15                   9
# 3                     180          114               7                   5
# 4                     186          165              11                   7
# 5                     186          115              13                  10
# 6                     186          119               8                   8
# 7                     186          212               9                   9
# 8                     181          179               7                   7
# 9                     198          134               8                   6
#
#    TRASLADOS  INDICE_OCUPACIONAL  PROMEDIO_CAMAS_DISPONIBLE  \
# 0         12               74.73                       6.00
# 1         21               61.31                       6.00
# 2         12               62.90                       6.00
# 3         17               70.00                       6.00
# 4         19               75.81                       6.00
# 5         10               72.58                       6.20
# 6         25               87.63                       6.00
# 7         22               85.48                       6.00
# 8         22               86.19                       6.03
# 9         22               68.69                       6.39
#
#    PROMEDIO_DIAS_ESTADA  LETALIDAD  INDICE_ROTACION
# 0                 12.78      77.78             1.50
# 1                 23.43      57.14             1.17
# 2                  6.53      60.00             2.50
# 3                 16.29      71.43             1.17
# 4                 15.00      63.64             1.83
# 5                  8.85      76.92             2.10
# 6                 14.88     100.00             1.33
# 7                 23.56     100.00             1.50
# 8                 25.57     100.00             1.16
# 9                 16.75      75.00             1.25
